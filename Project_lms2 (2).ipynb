# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("trainn.csv")

# %%
df
# Out:
#         Video_id category_id          channel_title  subscriber  \
# 0      HDR9SQc79          22           CaseyNeistat   9086142.0
# 1     KNH52UF?48          24        LastWeekTonight   5937292.0
# 2     QTW28IRG36          23           Rudy Mancuso   4191209.0
# 3     MGL76WI]26          24  Good Mythical Morning  13186408.0
# 4     TWP93KXT70          24               nigahiga  20563106.0
# ...          ...         ...                    ...         ...
# 3193  OKR48DOE67          20         EA SPORTS FIFA   3150213.0
# 3194  QJK69DS?91          10          JackWhiteVEVO    261596.0
# 3195  VHF51NVr11          10         JamesBlakeVEVO     28321.0
# 3196  XHU22OAJ39          26             Refinery29    890739.0
# 3197  IFD79NSG47          22                MN khan         0.0
#
#                                                   title  \
# 0                    WE WANT TO TALK ABOUT OUR MARRIAGE
# 1     The Trump Presidency: Last Week Tonight with J...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3198 entries, 0 to 3197
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Video_id               3198 non-null   object
#  1   category_id            3192 non-null   object
#  2   channel_title          3195 non-null   object
#  3   subscriber             3175 non-null   float64
#  4   title                  3195 non-null   object
#  5   tags                   3046 non-null   object
#  6   description            3133 non-null   object
#  7   Trend_day_count        3197 non-null   float64
#  8   Tag_count              3197 non-null   object
#  9   Trend_tag_count        3197 non-null   object
#  10  comment_count          3198 non-null   object
#  11  comment_disabled       3198 non-null   object
#  12  like dislike disabled  3198 non-null   object
#  13  likes                  3198 non-null   object
# ...

# %%
df=df.drop("Unnamed: 17",axis=1)

# %%
df=df.drop("Unnamed: 18",axis=1)

# %%
df
# Out:
#         Video_id category_id          channel_title  subscriber  \
# 0      HDR9SQc79          22           CaseyNeistat   9086142.0
# 1     KNH52UF?48          24        LastWeekTonight   5937292.0
# 2     QTW28IRG36          23           Rudy Mancuso   4191209.0
# 3     MGL76WI]26          24  Good Mythical Morning  13186408.0
# 4     TWP93KXT70          24               nigahiga  20563106.0
# ...          ...         ...                    ...         ...
# 3193  OKR48DOE67          20         EA SPORTS FIFA   3150213.0
# 3194  QJK69DS?91          10          JackWhiteVEVO    261596.0
# 3195  VHF51NVr11          10         JamesBlakeVEVO     28321.0
# 3196  XHU22OAJ39          26             Refinery29    890739.0
# 3197  IFD79NSG47          22                MN khan         0.0
#
#                                                   title  \
# 0                    WE WANT TO TALK ABOUT OUR MARRIAGE
# 1     The Trump Presidency: Last Week Tonight with J...
# ...

# %%
df.isnull().sum()
# Out:
# Video_id                   0
# category_id                6
# channel_title              3
# subscriber                23
# title                      3
# tags                     152
# description               65
# Trend_day_count            1
# Tag_count                  1
# Trend_tag_count            1
# comment_count              0
# comment_disabled           0
# like dislike disabled      0
# likes                      0
# dislike                    0
# tag appered in title       1
# views                      0
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#         Video_id category_id          channel_title  subscriber  \
# 0      HDR9SQc79          22           CaseyNeistat   9086142.0
# 1     KNH52UF?48          24        LastWeekTonight   5937292.0
# 2     QTW28IRG36          23           Rudy Mancuso   4191209.0
# 3     MGL76WI]26          24  Good Mythical Morning  13186408.0
# 4     TWP93KXT70          24               nigahiga  20563106.0
# ...          ...         ...                    ...         ...
# 3191   ISJ87JHs2          22           Grace Helbig   3008137.0
# 3193  OKR48DOE67          20         EA SPORTS FIFA   3150213.0
# 3194  QJK69DS?91          10          JackWhiteVEVO    261596.0
# 3195  VHF51NVr11          10         JamesBlakeVEVO     28321.0
# 3196  XHU22OAJ39          26             Refinery29    890739.0
#
#                                                   title  \
# 0                    WE WANT TO TALK ABOUT OUR MARRIAGE
# 1     The Trump Presidency: Last Week Tonight with J...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2980 entries, 0 to 3196
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Video_id               2980 non-null   object
#  1   category_id            2980 non-null   object
#  2   channel_title          2980 non-null   object
#  3   subscriber             2980 non-null   float64
#  4   title                  2980 non-null   object
#  5   tags                   2980 non-null   object
#  6   description            2980 non-null   object
#  7   Trend_day_count        2980 non-null   float64
#  8   Tag_count              2980 non-null   object
#  9   Trend_tag_count        2980 non-null   object
#  10  comment_count          2980 non-null   object
#  11  comment_disabled       2980 non-null   object
#  12  like dislike disabled  2980 non-null   object
#  13  likes                  2980 non-null   object
# ...

# %%
df.dtypes
# Out:
# Video_id                  object
# category_id               object
# channel_title             object
# subscriber               float64
# title                     object
# tags                      object
# description               object
# Trend_day_count          float64
# Tag_count                 object
# Trend_tag_count           object
# comment_count             object
# comment_disabled          object
# like dislike disabled     object
# likes                     object
# dislike                   object
# tag appered in title      object
# views                     object
# dtype: object

# %%
df["category_id"]=pd.to_numeric(df["category_id"])

# %%
df.dtypes
# Out:
# Video_id                  object
# category_id                int64
# channel_title             object
# subscriber               float64
# title                     object
# tags                      object
# description               object
# Trend_day_count          float64
# Tag_count                 object
# Trend_tag_count           object
# comment_count             object
# comment_disabled          object
# like dislike disabled     object
# likes                     object
# dislike                   object
# tag appered in title      object
# views                     object
# dtype: object

# %%
df["Trend_tag_count"]=df["Trend_tag_count"].replace('>',np.nan)
df=df.dropna()

# %%
df["Trend_tag_count"]=pd.to_numeric(df["Trend_tag_count"])
df.dtypes
# Out:
# Video_id                  object
# category_id                int64
# channel_title             object
# subscriber               float64
# title                     object
# tags                      object
# description               object
# Trend_day_count          float64
# Tag_count                 object
# Trend_tag_count            int64
# comment_count             object
# comment_disabled          object
# like dislike disabled     object
# likes                     object
# dislike                   object
# tag appered in title      object
# views                     object
# dtype: object

# %%
df["subscriber"]=pd.to_numeric(df["subscriber"])
df["Trend_day_count"]=pd.to_numeric(df["Trend_day_count"])
df["Tag_count"]=pd.to_numeric(df["Tag_count"])
df["comment_count"]=pd.to_numeric(df["comment_count"])
df["likes"]=pd.to_numeric(df["likes"])
df["dislike"]=pd.to_numeric(df["dislike"])
df["view"]=pd.to_numeric(df["view"])

df.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-60c7088fc1b0> in <module>
#       2 df["Trend_day_count"]=pd.to_numeric(df["Trend_day_count"])
#       3 df["Tag_count"]=pd.to_numeric(df["Tag_count"])
# ----> 4 df["comment_count"]=pd.to_numeric(df["comment_count"])
#       5 df["likes"]=pd.to_numeric(df["likes"])
#       6 df["dislike"]=pd.to_numeric(df["dislike"])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     150         coerce_numeric = errors not in ("ignore", "raise")
#     151         try:
# ...

# %%
df[df["comment_count"]==' ']
# Out:
#         Video_id  category_id        channel_title  subscriber  \
# 0      HDR9SQc79           22         CaseyNeistat   9086142.0
# 6     INH29DD?32           24  Saturday Night Live   5292034.0
# 14    SHP12LIj51           15      The king of DIY    725479.0
# 15     TAE9URl23           28       BostonDynamics    824219.0
# 16    MWG80DHU39           23              Cracked   2158902.0
# ...          ...          ...                  ...         ...
# 3190   PTM7WHf59           17                  NBA   8707071.0
# 3191   ISJ87JHs2           22         Grace Helbig   3008137.0
# 3193  OKR48DOE67           20       EA SPORTS FIFA   3150213.0
# 3194  QJK69DS?91           10        JackWhiteVEVO    261596.0
# 3195  VHF51NVr11           10       JamesBlakeVEVO     28321.0
#
#                                                   title  \
# 0                    WE WANT TO TALK ABOUT OUR MARRIAGE
# 6             Roy Moore & Jeff Sessions Cold Open - SNL
# ...

# %%
df["comment_count"]=df["comment_count"].replace(' ',0)
df
# Out:
#         Video_id  category_id          channel_title  subscriber  \
# 0      HDR9SQc79           22           CaseyNeistat   9086142.0
# 1     KNH52UF?48           24        LastWeekTonight   5937292.0
# 2     QTW28IRG36           23           Rudy Mancuso   4191209.0
# 3     MGL76WI]26           24  Good Mythical Morning  13186408.0
# 4     TWP93KXT70           24               nigahiga  20563106.0
# ...          ...          ...                    ...         ...
# 3191   ISJ87JHs2           22           Grace Helbig   3008137.0
# 3193  OKR48DOE67           20         EA SPORTS FIFA   3150213.0
# 3194  QJK69DS?91           10          JackWhiteVEVO    261596.0
# 3195  VHF51NVr11           10         JamesBlakeVEVO     28321.0
# 3196  XHU22OAJ39           26             Refinery29    890739.0
#
#                                                   title  \
# 0                    WE WANT TO TALK ABOUT OUR MARRIAGE
# 1     The Trump Presidency: Last Week Tonight with J...
# ...

# %%
df.dtypes
# Out:
# Video_id                  object
# category_id                int64
# channel_title             object
# subscriber               float64
# title                     object
# tags                      object
# description               object
# Trend_day_count          float64
# Tag_count                  int64
# Trend_tag_count            int64
# comment_count             object
# comment_disabled          object
# like dislike disabled     object
# likes                     object
# dislike                   object
# tag appered in title      object
# views                     object
# dtype: object

# %%
df["comment_count"]=pd.to_numeric(df["comment_count"])

# %%
df["likes"]=pd.to_numeric(df["likes"])

# %%
df["dislike"]=pd.to_numeric(df["dislike"])

# %%
df["views"]=pd.to_numeric(df["views"])

# %%
df.dtypes
# Out:
# Video_id                  object
# category_id                int64
# channel_title             object
# subscriber               float64
# title                     object
# tags                      object
# description               object
# Trend_day_count          float64
# Tag_count                  int64
# Trend_tag_count            int64
# comment_count              int64
# comment_disabled          object
# like dislike disabled     object
# likes                      int64
# dislike                    int64
# tag appered in title      object
# views                      int64
# dtype: object

# %%
df
# Out:
#         Video_id  category_id          channel_title  subscriber  \
# 0      HDR9SQc79           22           CaseyNeistat   9086142.0
# 1     KNH52UF?48           24        LastWeekTonight   5937292.0
# 2     QTW28IRG36           23           Rudy Mancuso   4191209.0
# 3     MGL76WI]26           24  Good Mythical Morning  13186408.0
# 4     TWP93KXT70           24               nigahiga  20563106.0
# ...          ...          ...                    ...         ...
# 3191   ISJ87JHs2           22           Grace Helbig   3008137.0
# 3193  OKR48DOE67           20         EA SPORTS FIFA   3150213.0
# 3194  QJK69DS?91           10          JackWhiteVEVO    261596.0
# 3195  VHF51NVr11           10         JamesBlakeVEVO     28321.0
# 3196  XHU22OAJ39           26             Refinery29    890739.0
#
#                                                   title  \
# 0                    WE WANT TO TALK ABOUT OUR MARRIAGE
# 1     The Trump Presidency: Last Week Tonight with J...
# ...

# %%
#dropping rows with 0 comments or 0 likes
df["comment_count"]=df["comment_count"].replace([0],np.nan)

# %%
df
# Out:
#         Video_id  category_id          channel_title  subscriber  \
# 0      HDR9SQc79           22           CaseyNeistat   9086142.0
# 1     KNH52UF?48           24        LastWeekTonight   5937292.0
# 2     QTW28IRG36           23           Rudy Mancuso   4191209.0
# 3     MGL76WI]26           24  Good Mythical Morning  13186408.0
# 4     TWP93KXT70           24               nigahiga  20563106.0
# ...          ...          ...                    ...         ...
# 3191   ISJ87JHs2           22           Grace Helbig   3008137.0
# 3193  OKR48DOE67           20         EA SPORTS FIFA   3150213.0
# 3194  QJK69DS?91           10          JackWhiteVEVO    261596.0
# 3195  VHF51NVr11           10         JamesBlakeVEVO     28321.0
# 3196  XHU22OAJ39           26             Refinery29    890739.0
#
#                                                   title  \
# 0                    WE WANT TO TALK ABOUT OUR MARRIAGE
# 1     The Trump Presidency: Last Week Tonight with J...
# ...

# %%
df["likes"]=df["likes"].replace([0],np.nan)

# %%
df=df.dropna()

# %%
df
# Out:
#         Video_id  category_id       channel_title  subscriber  \
# 1     KNH52UF?48           24     LastWeekTonight   5937292.0
# 5     JDJ37HWR29           28            iJustine   4652602.0
# 7     ENJ69DGJ93           28  CrazyRussianHacker  10474796.0
# 8     ZXD32BTa68            1    20th Century Fox   2453494.0
# 10    BQQ21ZVm59           17                 NFL   3212413.0
# ...          ...          ...                 ...         ...
# 3186   XXL70JLC3           10    XAmbassadorsVEVO    659876.0
# 3187  SUY38OYl84           10           dodieVEVO    356570.0
# 3188  AVI91YQD43           24             Variety    230720.0
# 3189  UGJ10XAb33           26         AmazingPhil   4232293.0
# 3196  XHU22OAJ39           26          Refinery29    890739.0
#
#                                                   title  \
# 1     The Trump Presidency: Last Week Tonight with J...
# 5                                 2 Weeks with iPhone X
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1507 entries, 1 to 3196
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Video_id               1507 non-null   object
#  1   category_id            1507 non-null   int64
#  2   channel_title          1507 non-null   object
#  3   subscriber             1507 non-null   float64
#  4   title                  1507 non-null   object
#  5   tags                   1507 non-null   object
#  6   description            1507 non-null   object
#  7   Trend_day_count        1507 non-null   float64
#  8   Tag_count              1507 non-null   int64
#  9   Trend_tag_count        1507 non-null   int64
#  10  comment_count          1507 non-null   float64
#  11  comment_disabled       1507 non-null   object
#  12  like dislike disabled  1507 non-null   object
#  13  likes                  1507 non-null   float64
# ...

# %%
import seaborn as sns

# %%
df.pivot_table(values=['likes','views','comment_count'],index=['category_id',"Video_id"])
# Out:
#                         comment_count    likes    views
# category_id Video_id
# 1           AAU19XZI83       137344.0  11670.0   568961
#             APA50GMQ87       162000.0  19173.0   940884
#             BEF83FJi95        28585.0   5167.0  1668547
#             BSN33BJs60       109576.0  18086.0   409859
#             BXZ12GPB47       154448.0  14853.0   490193
# ...                               ...      ...      ...
# 28          YGA74IYS90        54584.0  10198.0  1309252
#             YHE79OXJ22       283886.0  16492.0   797159
#             YRQ80WZp51       277830.0  17272.0   972418
# 29          NPI24IOl66       170749.0  16477.0   455542
#             SNA22ST@17       240245.0   5467.0   628055
#
# [1507 rows x 3 columns]

# %%
sns.countplot(df['category_id'])
# Out:
# <AxesSubplot:xlabel='category_id', ylabel='count'>

# %%
plt.plot(df['category_id'],df['views'])

# %%
plt.plot(df['category_id'],df['likes'])

# %%
plt.bar(df['category_id'],df['comment_count'])
# Out:
# <BarContainer object of 1507 artists>

# %%
plt.hist(df['category_id'],bins=10)
# Out:
# (array([ 95.,   0.,   0., 210.,   0., 133.,  32., 237., 667., 133.]),
#  array([ 1. ,  3.8,  6.6,  9.4, 12.2, 15. , 17.8, 20.6, 23.4, 26.2, 29. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(df['category_id'],df['likes'])
# Out:
# <BarContainer object of 1507 artists>

# %%
plt.bar(df['category_id'],df['views'])
# Out:
# <BarContainer object of 1507 artists>

# %%
sns.distplot(df['category_id'])
# Out:
# <AxesSubplot:xlabel='category_id', ylabel='Density'>

# %%
df
# Out:
#         Video_id  category_id       channel_title  subscriber  \
# 1     KNH52UF?48           24     LastWeekTonight   5937292.0
# 5     JDJ37HWR29           28            iJustine   4652602.0
# 7     ENJ69DGJ93           28  CrazyRussianHacker  10474796.0
# 8     ZXD32BTa68            1    20th Century Fox   2453494.0
# 10    BQQ21ZVm59           17                 NFL   3212413.0
# ...          ...          ...                 ...         ...
# 3186   XXL70JLC3           10    XAmbassadorsVEVO    659876.0
# 3187  SUY38OYl84           10           dodieVEVO    356570.0
# 3188  AVI91YQD43           24             Variety    230720.0
# 3189  UGJ10XAb33           26         AmazingPhil   4232293.0
# 3196  XHU22OAJ39           26          Refinery29    890739.0
#
#                                                   title  \
# 1     The Trump Presidency: Last Week Tonight with J...
# 5                                 2 Weeks with iPhone X
# ...

# %%
df.dtypes
# Out:
# Video_id                  object
# category_id                int64
# channel_title             object
# subscriber               float64
# title                     object
# tags                      object
# description               object
# Trend_day_count          float64
# Tag_count                  int64
# Trend_tag_count            int64
# comment_count            float64
# comment_disabled          object
# like dislike disabled     object
# likes                    float64
# dislike                    int64
# tag appered in title      object
# views                      int64
# dtype: object

# %%
#replacing True with 1 and False with 0 in comment_disabled,like dislike disabled,tag appered in the title
a={"TRUE":1,"FALSE":0}
df["comment_disabled"]=df["comment_disabled"].map(a)
df
# Out:
#         Video_id  category_id       channel_title  subscriber  \
# 1     KNH52UF?48           24     LastWeekTonight   5937292.0
# 5     JDJ37HWR29           28            iJustine   4652602.0
# 7     ENJ69DGJ93           28  CrazyRussianHacker  10474796.0
# 8     ZXD32BTa68            1    20th Century Fox   2453494.0
# 10    BQQ21ZVm59           17                 NFL   3212413.0
# ...          ...          ...                 ...         ...
# 3186   XXL70JLC3           10    XAmbassadorsVEVO    659876.0
# 3187  SUY38OYl84           10           dodieVEVO    356570.0
# 3188  AVI91YQD43           24             Variety    230720.0
# 3189  UGJ10XAb33           26         AmazingPhil   4232293.0
# 3196  XHU22OAJ39           26          Refinery29    890739.0
#
#                                                   title  \
# 1     The Trump Presidency: Last Week Tonight with J...
# 5                                 2 Weeks with iPhone X
# ...

# %%
df["like dislike disabled"]=df["like dislike disabled"].map(a)
df
# Out:
#         Video_id  category_id       channel_title  subscriber  \
# 1     KNH52UF?48           24     LastWeekTonight   5937292.0
# 5     JDJ37HWR29           28            iJustine   4652602.0
# 7     ENJ69DGJ93           28  CrazyRussianHacker  10474796.0
# 8     ZXD32BTa68            1    20th Century Fox   2453494.0
# 10    BQQ21ZVm59           17                 NFL   3212413.0
# ...          ...          ...                 ...         ...
# 3186   XXL70JLC3           10    XAmbassadorsVEVO    659876.0
# 3187  SUY38OYl84           10           dodieVEVO    356570.0
# 3188  AVI91YQD43           24             Variety    230720.0
# 3189  UGJ10XAb33           26         AmazingPhil   4232293.0
# 3196  XHU22OAJ39           26          Refinery29    890739.0
#
#                                                   title  \
# 1     The Trump Presidency: Last Week Tonight with J...
# 5                                 2 Weeks with iPhone X
# ...

# %%
df['tag appered in title'].unique()
# Out:
# array([False,  True])

# %%
b={"False":0,"  True":1}

# %%
df['tag appered in title']=df['tag appered in title'].astype('int')
df
# Out:
#         Video_id  category_id       channel_title  subscriber  \
# 1     KNH52UF?48           24     LastWeekTonight   5937292.0
# 5     JDJ37HWR29           28            iJustine   4652602.0
# 7     ENJ69DGJ93           28  CrazyRussianHacker  10474796.0
# 8     ZXD32BTa68            1    20th Century Fox   2453494.0
# 10    BQQ21ZVm59           17                 NFL   3212413.0
# ...          ...          ...                 ...         ...
# 3186   XXL70JLC3           10    XAmbassadorsVEVO    659876.0
# 3187  SUY38OYl84           10           dodieVEVO    356570.0
# 3188  AVI91YQD43           24             Variety    230720.0
# 3189  UGJ10XAb33           26         AmazingPhil   4232293.0
# 3196  XHU22OAJ39           26          Refinery29    890739.0
#
#                                                   title  \
# 1     The Trump Presidency: Last Week Tonight with J...
# 5                                 2 Weeks with iPhone X
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1507 entries, 1 to 3196
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Video_id               1507 non-null   object
#  1   category_id            1507 non-null   int64
#  2   channel_title          1507 non-null   object
#  3   subscriber             1507 non-null   float64
#  4   title                  1507 non-null   object
#  5   tags                   1507 non-null   object
#  6   description            1507 non-null   object
#  7   Trend_day_count        1507 non-null   float64
#  8   Tag_count              1507 non-null   int64
#  9   Trend_tag_count        1507 non-null   int64
#  10  comment_count          1507 non-null   float64
#  11  comment_disabled       1507 non-null   int64
#  12  like dislike disabled  1507 non-null   int64
#  13  likes                  1507 non-null   float64
# ...

# %%
#encoding using label encoder
from sklearn.preprocessing import LabelEncoder
df["Video_id"]=LabelEncoder().fit_transform(df["Video_id"])
df["channel_title"]=LabelEncoder().fit_transform(df["channel_title"])
df["title"]=LabelEncoder().fit_transform(df["title"])

# %%
df
# Out:
#       Video_id  category_id  channel_title  subscriber  title  \
# 1          642           24            361   5937292.0   1263
# 5          537           28            780   4652602.0     30
# 7          291           28            149  10474796.0     55
# 8         1500            1              1   2453494.0   1219
# 10         108           17            462   3212413.0    317
# ...        ...          ...            ...         ...    ...
# 3186      1383           10            748    659876.0   1461
# 3187      1104           10            767    356570.0   1488
# 3188        53           24            721    230720.0    251
# 3189      1184           26             23   4232293.0    580
# 3196      1349           26            546    890739.0    790
#
#                                                    tags  \
# 1     last week tonight trump presidency|last week t...
# 5     ijustine|week with iPhone X|iphone x|apple|iph...
# ...

# %%
#dropping tags and description column
df.drop(["tags","description"],axis=1,inplace=True)

# %%
df
# Out:
#       Video_id  category_id  channel_title  subscriber  title  \
# 1          642           24            361   5937292.0   1263
# 5          537           28            780   4652602.0     30
# 7          291           28            149  10474796.0     55
# 8         1500            1              1   2453494.0   1219
# 10         108           17            462   3212413.0    317
# ...        ...          ...            ...         ...    ...
# 3186      1383           10            748    659876.0   1461
# 3187      1104           10            767    356570.0   1488
# 3188        53           24            721    230720.0    251
# 3189      1184           26             23   4232293.0    580
# 3196      1349           26            546    890739.0    790
#
#       Trend_day_count  Tag_count  Trend_tag_count  comment_count  \
# 1                 1.0         23                1       116266.0
# 5                10.0          9                1       198248.0
# ...

# %%
df.dtypes
# Out:
# Video_id                   int32
# category_id                int64
# channel_title              int32
# subscriber               float64
# title                      int32
# Trend_day_count          float64
# Tag_count                  int64
# Trend_tag_count            int64
# comment_count            float64
# comment_disabled           int64
# like dislike disabled      int64
# likes                    float64
# dislike                    int64
# tag appered in title       int32
# views                      int64
# dtype: object

# %%
c=df.corr()
sns.heatmap(c)
plt.show()

# %%
plt.scatter(df["category_id"],df["likes"])

# %%
plt.plot(df["category_id"],df["views"])

# %%
sns.countplot(df["category_id"])
# Out:
# <AxesSubplot:xlabel='category_id', ylabel='count'>

# %%
plt.scatter(df["comment_count"],df["likes"])

# %%
plt.scatter(df["Tag_count"],df["views"])

# %%
plt.plot(df["likes"])

# %%
plt.plot(df["subscriber"],df["likes"])

# %%
plt.boxplot(df["comment_count"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a697b89460>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a697b89b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a697b89100>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a697b92250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a697b925b0>],
#  'means': []}

# %%
plt.bar(df["category_id"],df["comment_count"])
# Out:
# <BarContainer object of 1507 artists>
